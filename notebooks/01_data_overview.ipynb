# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/Amazon Sale Report.csv', sep=',', low_memory=False)
display(df.head())
display(df.info())
display(df.describe())
display(df.isna().sum())
display(df.sample(10))
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB
# None
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64
#        index             Order ID      Date                        Status  \
# 80417  80417  405-5676828-5362754  05-06-22  Shipped - Delivered to Buyer
# 97931  97931  402-6584413-8163540  06-23-22                       Shipped
# 25892  25892  403-5210060-8615555  04-15-22                       Shipped
# 85858  85858  171-2625799-7964336  05-03-22                     Cancelled
# 98061  98061  405-1835553-0477907  06-23-22                       Shipped
# 78336  78336  171-4320580-2142752  05-08-22  Shipped - Delivered to Buyer
# 17065  17065  405-7452910-3685112  04-20-22  Shipped - Delivered to Buyer
# 35600  35600  403-6915228-1425125  04-09-22                       Shipped
# 73439  73439  402-9199029-7266765  05-12-22                       Shipped
# 25807  25807  408-0059694-2327561  04-15-22  Shipped - Delivered to Buyer
#
#       Fulfilment Sales Channel  ship-service-level    Style             SKU  \
# 80417   Merchant      Amazon.in           Standard   SET377  SET377-KR-NP-S
# 97931     Amazon      Amazon.in          Expedited    J0008  J0008-SKD-XXXL
# 25892     Amazon      Amazon.in          Expedited    J0003     J0003-SET-L
# 85858     Amazon      Amazon.in          Expedited    J0006     J0006-SET-M
# 98061     Amazon      Amazon.in          Expedited    J0117      J0117-TP-S
# 78336   Merchant      Amazon.in           Standard    J0164      J0164-DR-L
# 17065   Merchant      Amazon.in           Standard    J0339      J0339-DR-L
# 35600     Amazon      Amazon.in          Expedited    J0339     J0339-DR-XL
# 73439     Amazon      Amazon.in          Expedited    J0297      J0297-TP-L
# 25807   Merchant      Amazon.in           Standard  JNE3457  JNE3457-KR-XXL
#
#             Category  ... currency  Amount           ship-city  \
# 80417            Set  ...      INR  1036.0           BENGALURU
# 97931            Set  ...      INR  1075.0             GWALIOR
# 25892            Set  ...      INR   696.0  Guwahati, Maligaon
# 85858   Ethnic Dress  ...      INR   845.0              BHILAI
# 98061            Top  ...      INR   726.0              MUMBAI
# 78336   Ethnic Dress  ...      INR   362.0              BHOPAL
# 17065  Western Dress  ...      INR   744.0             LUCKNOW
# 35600  Western Dress  ...      INR   744.0         KURUKSHETRA
# 73439            Top  ...      INR   574.0          JALPAIGURI
# 25807          kurta  ...      INR   333.0           BENGALURU
#
#            ship-state ship-postal-code  ship-country  \
# 80417       KARNATAKA         560084.0            IN
# 97931  MADHYA PRADESH         474001.0            IN
# 25892           ASSAM         781012.0            IN
# 85858    CHHATTISGARH         490020.0            IN
# 98061     MAHARASHTRA         400092.0            IN
# 78336  MADHYA PRADESH         462016.0            IN
# 17065   UTTAR PRADESH         226010.0            IN
# 35600         HARYANA         136118.0            IN
# 73439     WEST BENGAL         735202.0            IN
# 25807       KARNATAKA         560005.0            IN
#
#                                            promotion-ids    B2B  fulfilled-by  \
# 80417  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 97931                                                NaN  False           NaN
# 25892       IN Core Free Shipping 2015/04/08 23-48-5-108  False           NaN
# 85858                                                NaN  False           NaN
# 98061                                                NaN  False           NaN
# 78336  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 17065  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 35600       IN Core Free Shipping 2015/04/08 23-48-5-108  False           NaN
# 73439       IN Core Free Shipping 2015/04/08 23-48-5-108  False           NaN
# 25807  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
#
#       Unnamed: 22
# 80417       False
# 97931       False
# 25892         NaN
# 85858       False
# 98061       False
# 78336       False
# 17065         NaN
# 35600         NaN
# 73439       False
# 25807         NaN
#
# [10 rows x 24 columns]

# %%
data = pd.read_csv('../data/raw/Sale Report.csv', sep=',', low_memory=False)
df = pd.DataFrame(data)
display(df.head())
display(df.info())
display(df.describe())
display(df.isna().sum())
display(df.sample(10))
# Out:
#    index       SKU Code Design No.  Stock       Category Size Color
# 0      0    AN201-RED-L      AN201    5.0  AN : LEGGINGS    L   Red
# 1      1    AN201-RED-M      AN201    5.0  AN : LEGGINGS    M   Red
# 2      2    AN201-RED-S      AN201    3.0  AN : LEGGINGS    S   Red
# 3      3   AN201-RED-XL      AN201    6.0  AN : LEGGINGS   XL   Red
# 4      4  AN201-RED-XXL      AN201    3.0  AN : LEGGINGS  XXL   Red
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9271 entries, 0 to 9270
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       9271 non-null   int64
#  1   SKU Code    9188 non-null   object
#  2   Design No.  9235 non-null   object
#  3   Stock       9235 non-null   float64
#  4   Category    9226 non-null   object
#  5   Size        9235 non-null   object
#  6   Color       9226 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 507.1+ KB
# None
#              index        Stock
# count  9271.000000  9235.000000
# mean   4635.000000    26.246454
# std    2676.451507    58.462891
# min       0.000000     0.000000
# 25%    2317.500000     3.000000
# 50%    4635.000000     8.000000
# 75%    6952.500000    31.000000
# max    9270.000000  1234.000000
# index          0
# SKU Code      83
# Design No.    36
# Stock         36
# Category      45
# Size          36
# Color         45
# dtype: int64
#       index           SKU Code Design No.  Stock       Category  Size  \
# 8397   8397  SET288-KR-NP-XXXL     SET288    6.0            SET  XXXL
# 3524   3524   JNE2307-KR-572-M    JNE2307    1.0          KURTA     M
# 1344   1344         J0133-KR-M      J0133    3.0          KURTA     M
# 1217   1217         J0113-TP-L      J0113  109.0            TOP     L
# 57       57      AN213-BROWN-S      AN213    8.0  AN : LEGGINGS     S
# 6883   6883      MEN5022-KR-XL    MEN5022    2.0          KURTA    XL
# 6005   6005     JNE3786-KR-XXL    JNE3786   19.0          KURTA   XXL
# 756     756        J0025-DR-XS      J0025    7.0          DRESS    XS
# 9097   9097     SET410-KR-NP-S     SET410   36.0            SET     S
# 1677   1677      J0181-TP-XXXL      J0181    1.0            TOP  XXXL
#
#           Color
# 8397       Grey
# 3524       Grey
# 1344     Maroon
# 1217       Blue
# 57        Brown
# 6883      Green
# 6005      Black
# 756   Sea Green
# 9097      Green
# 1677       Pink
